# %% [markdown]
# <a href="https://colab.research.google.com/github/ZEKOVIX/Quantitative-trading-strategies/blob/main/Test%201%20Github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 2
b = 3
c = a*b

# %%
print(c)
# Out:
# 6
